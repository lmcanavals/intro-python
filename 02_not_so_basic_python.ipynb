# %% [markdown]
# <a href="https://colab.research.google.com/github/pcsilcan/intro-python/blob/master/02_not_so_basic_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python no tan básico

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
mat = np.random.rand(100, 2)
print(mat[:5, :])
# Out:
# [[0.96037486 0.46077368]
#  [0.81503972 0.94243838]
#  [0.03719611 0.48176647]
#  [0.56217698 0.30248678]
#  [0.95149813 0.39211869]]

# %%
plt.plot(mat)

# %%
x = mat[:, 0]
y = mat[:, 1]
plt.scatter(x, y)
